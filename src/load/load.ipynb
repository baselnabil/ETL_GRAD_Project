# %%
from sqlalchemy import create_engine
from pyspark.sql import SparkSession
import pandas as pd

# %%
spark = SparkSession.builder\
        .appName('loader')\
        .getOrCreate()

# %%
df = spark.read.parquet('../../data/final/part-00000-a868eb3f-41a7-4a9b-b1c3-d8027fbc07ce-c000.snappy.parquet')
pandas_df = df.toPandas()
pandas_df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 33063       2020               SE              FT             Data Scientist
# 33064       2021               MI              FT   Principal Data Scientist
# 33065       2020               EN              FT             Data Scientist
# 33066       2020               EN              CT      Business Data Analyst
# 33067       2021               SE              FT       Data Science Manager
#
#         salary salary_currency salary_in_usd employee_residence  remote_ratio  \
# 0       202730             USD        202730                 US             0
# 1        92118             USD         92118                 US             0
# 2       130500             USD        130500                 US             0
# 3        96000             USD         96000                 US             0
# 4       190000             USD        190000                 US             0
# ...        ...             ...           ...                ...           ...
# 33063   412000             USD        412000                 US           100
# 33064   151000             USD        151000                 US           100
# 33065   105000             USD        105000                 US           100
# 33066   100000             USD        100000                 US           100
# 33067  7000000             INR         94665                 IN            50
#
#       company_location company_size
# 0                   US            M
# 1                   US            M
# 2                   US            M
# 3                   US            M
# 4                   US            M
# ...                ...          ...
# 33063               US            L
# 33064               US            L
# 33065               US            S
# 33066               US            L
# 33067               IN            L
#
# [33068 rows x 11 columns]

# %%
engine= create_engine('postgresql://airflow:airflow@localhost:5432/airflow')

# %%
pandas_df.to_sql('job_data',engine,if_exists="replace",index=False)
print('data has been writted to postgresql')
# Out:
# data has been writted to postgresql
