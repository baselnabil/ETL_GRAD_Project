# %%
import pandas as pd 
from sqlalchemy import create_engine
import sqlalchemy as db

# %%
postgresql_engine = create_engine('postgresql://airflow:airflow@localhost:5432/airflow')
mariadb_engine = create_engine("mysql://root:root@127.0.0.1:3306/model")

# %%
connection = postgresql_engine.connect()
metadata= db.MetaData()
staging_data = db.Table('staging_data', metadata, schema='public', autoload_with=postgresql_engine)

# %%
df = pd.read_sql('SELECT * FROM archived_staging_data',con=postgresql_engine)
df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 33063       2020               SE              FT             Data Scientist
# 33064       2021               MI              FT   Principal Data Scientist
# 33065       2020               EN              FT             Data Scientist
# 33066       2020               EN              CT      Business Data Analyst
# 33067       2021               SE              FT       Data Science Manager
#
# ...

# %%
df.to_sql('big_table',mariadb_engine,if_exists='append',index=False)
# Out:
# 33068
