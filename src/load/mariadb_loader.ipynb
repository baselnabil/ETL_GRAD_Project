# %%
import pandas as pd 
from sqlalchemy import create_engine
import sqlalchemy as db

# %%
postgresql_engine = create_engine('postgresql://airflow:airflow@localhost:5432/airflow')
# mariadb_engine = create_engine("mariadb+mariadbconnector://basel:baselnabil@127.0.0.1:3306/model")

# %%
connection = postgresql_engine.connect()
metadata= db.MetaData()
staging_data = db.Table('staging_data', metadata, schema='public', autoload_with=postgresql_engine)
# Out:
# ['work_year', 'experience_level', 'employment_type', 'job_title', 'salary', 'salary_currency', 'salary_in_usd', 'employee_residence', 'remote_ratio', 'company_location', 'company_size', 'load_time']

# %%
df = pd.read_sql('SELECT * FROM staging_data',con=postgresql_engine)
df
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/main/Grad_proj/.myenv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/main/Grad_proj/.myenv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "staging_model" does not exist
# LINE 1: SELECT * FROM staging_model
#                       ^
#
#
# ...
